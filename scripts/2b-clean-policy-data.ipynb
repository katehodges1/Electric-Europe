# %% [markdown]
# # Clean Policy Incentives Data to Prepare For Vectorisation
# * Uses policy_incentives_subsectioned.csv created in script 1a
# * Clean and tokenise data using spacy package

# %%
import configparser
import pandas as pd
import numpy as np
import os
import time
import spacy
from spacy import displacy
import string
from pathlib import Path

# %%
nlp = spacy.load('en_core_web_sm')

# %%
config = configparser.ConfigParser()
config.read("config.ini")

# access values
raw_path = Path(config["default"]["raw_path"])
interim_path = Path(config["default"]["interim_path"])
processed_path = Path(config["default"]["processed_path"])

# %% [markdown]
# Read in data & ensure stored as strings

# %%
df = pd.read_csv(interim_path/"policy_incentives_subsectioned.csv")

#df["text"] = df["text"].fillna("")
df = df.dropna(subset=['text'])
df.astype(str)
# Out:
#             country                                            section  \
# 0           Austria                                 Purchase subsidies
# 1           Austria                          Registration tax benefits
# 2           Austria               Ownership / Circulation Tax Benefits
# 3           Austria                               Company tax benefits
# 4           Austria                                       VAT benefits
# ..              ...                                                ...
# 312  United Kingdom                          Registration tax benefits
# 313  United Kingdom                             Ownership tax benefits
# 314  United Kingdom                               Company tax benefits
# 315  United Kingdom                       AF infrastructure incentives
# 316  United Kingdom  Announced policy changes (effective later in 2...
#
#                                                   text
# 0    The federal purchase subsidy scheme “E-Mobilit...
# 1    BEVs are fully exempt from the NoVA registrati...
# 2    As of 1 April 2025, BEVs are no longer exempt ...
# 3    Zero-emission vehicles benefit from exemption ...
# 4    Companies may deduct VAT fully for BEVs priced...
# ..                                                 ...
# 312                         Vehicle Excise Duty (VED):
# 313                         Vehicle Excise Duty (VED):
# 314  Benefit-in-Kind (BiK) Tax: First-Year Capital ...
# 315  'Electric Vehicle Homecharge Scheme (EVHS): Pr...
# 316  Zero Emission Vehicle (ZEV) Mandate: Public In...
#
# [280 rows x 3 columns]

# %%
# tokenise, remove capitalisation, experiment with removing stop words
    # keep numbers, skip lemmatisation - tense will be important here

# define custom stopwords list - removing filler words but ensuring some policy relevant words are kept (such as from, per, until...)
custom_stopwords = {
    "the",  "a", "an", "and", "or", "of", "this", "that", "these", "those",
    "which", "such", "as", "etc"
}

# define function to clean & preprocess entire dataframe
def preprocess_text(spacy_doc: spacy.tokens.doc.Doc) -> str:
    text_clean = [token.text.lower() 
                  for token in spacy_doc 
                  if not token.is_space
                  and not token.is_punct
                  and token.text.lower() not in custom_stopwords
                
]
    return " ".join(text_clean)

# %%
# apply cleaning to each row
df["text_clean"] = df["text"].apply(lambda x: preprocess_text(nlp(x)))
#df_clean = df.apply(lambda x: preprocess_text(nlp(x)))

#quick check
print(df[["text", "text_clean"]].head())
#print(df, df_clean)
# Out:
#                                                 text  \
# 0  The federal purchase subsidy scheme “E-Mobilit...
# 1  BEVs are fully exempt from the NoVA registrati...
# 2  As of 1 April 2025, BEVs are no longer exempt ...
# 3  Zero-emission vehicles benefit from exemption ...
# 4  Companies may deduct VAT fully for BEVs priced...
#
#                                           text_clean
# 0  federal purchase subsidy scheme e mobilität 20...
# 1   bevs are fully exempt from nova registration tax
# 2  1 april 2025 bevs are no longer exempt from mo...
# 3  zero emission vehicles benefit from exemption ...
# 4  companies may deduct vat fully for bevs priced...

# %%
df
# Out:
#             country                                            section  \
# 0           Austria                                 Purchase subsidies
# 1           Austria                          Registration tax benefits
# 2           Austria               Ownership / Circulation Tax Benefits
# 3           Austria                               Company tax benefits
# 4           Austria                                       VAT benefits
# ..              ...                                                ...
# 312  United Kingdom                          Registration tax benefits
# 313  United Kingdom                             Ownership tax benefits
# 314  United Kingdom                               Company tax benefits
# 315  United Kingdom                       AF infrastructure incentives
# 316  United Kingdom  Announced policy changes (effective later in 2...
#
#                                                   text  \
# 0    The federal purchase subsidy scheme “E-Mobilit...
# 1    BEVs are fully exempt from the NoVA registrati...
# 2    As of 1 April 2025, BEVs are no longer exempt ...
# 3    Zero-emission vehicles benefit from exemption ...
# 4    Companies may deduct VAT fully for BEVs priced...
# ..                                                 ...
# 312                         Vehicle Excise Duty (VED):
# 313                         Vehicle Excise Duty (VED):
# 314  Benefit-in-Kind (BiK) Tax: First-Year Capital ...
# 315  'Electric Vehicle Homecharge Scheme (EVHS): Pr...
# 316  Zero Emission Vehicle (ZEV) Mandate: Public In...
#
#                                             text_clean
# 0    federal purchase subsidy scheme e mobilität 20...
# 1     bevs are fully exempt from nova registration tax
# 2    1 april 2025 bevs are no longer exempt from mo...
# 3    zero emission vehicles benefit from exemption ...
# 4    companies may deduct vat fully for bevs priced...
# ..                                                 ...
# 312                            vehicle excise duty ved
# 313                            vehicle excise duty ved
# 314  benefit in kind bik tax first year capital all...
# 315  electric vehicle homecharge scheme evhs provid...
# 316  zero emission vehicle zev mandate public inves...
#
# [280 rows x 4 columns]

# %%
# save cleaned df 
df_cleaned = df.drop(columns="text")

df_cleaned.to_csv(interim_path/"tokenised_policy_incentives_subsectioned.csv", index = False)

# %%
# concat subsections to get one 'document' per country
# Group by 'country' and concatenate strings in 'text_clean'
country_groupings = df.groupby('country')['text_clean'].agg(' '.join).reset_index()

# %%
country_groupings
# Out:
#            country                                         text_clean
# 0          Austria  federal purchase subsidy scheme e mobilität 20...
# 1          Belgium  regional purchase subsidies are no longer avai...
# 2         Bulgaria  no purchase subsidies are currently available ...
# 3          Croatia  call for investment in zero emission vehicles ...
# 4           Cyprus  under national electromobility promotion schem...
# 5   Czech Republic  no purchase subsidies available in 2025 bevs f...
# 6          Denmark  no direct national purchase subsidies are avai...
# 7          Estonia  since december 2023 estonia no longer offers d...
# 8          Finland  2025 finland does not offer direct purchase su...
# 9           France  ecological bonus bonus écologique remains in p...
# 10         Germany  april 2025 germany no longer offers national p...
# 11          Greece  greece 's i move electrically 3 programme offe...
# 12         Hungary  bevs used for business purposes are exempt fro...
# 13         Iceland  grants for electric car purchases ranging from...
# 14         Ireland  sustainable energy authority ireland seai prov...
# 15           Italy  registration fee ipt italy has no co₂-based ca...
# 16          Latvia  2025 there are no active national purchase sub...
# 17   Liechtenstein  no national purchase subsidies for bevs in pla...
# 18       Lithuania  purchase incentives bonus for individuals in 2...
# 19      Luxembourg  maximum subsidy € 6,000 is available for new b...
# 20           Malta  cars m1 vans n1 ≤ 3,500 kg optional scrappage ...
# 21     Netherlands  no national purchase subsidies are available i...
# 22          Norway  no national purchase subsidies are available f...
# 23          Poland  naszeauto programme launched on 3 february 202...
# 24        Portugal  in 2025 private individuals in portugal can re...
# 25         Romania  conditions bevs are completely exempt from reg...
# 26        Slovakia  no direct bev purchase subsidies in place 2025...
# 27        Slovenia  private individuals can receive up to legal en...
# 28           Spain  spain 's moves iii programme extended through ...
# 29          Sweden  no bev specific registration tax benefit swede...
# 30     Switzerland  no federal purchase subsidies regional subsidi...
# 31          Turkey  no national direct purchase subsidies for bevs...
# 32  United Kingdom  electric car grant ecg introduced 16 july 2025...

# %%
country_groupings.to_csv(interim_path/"tokenised_policy_incentives_country.csv", index=False)
