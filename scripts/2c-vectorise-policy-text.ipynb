# %% [markdown]
# ## Feed Policy Text data into sentence-transformer to get position in vector space

# %%
import configparser
from pathlib import Path
import pandas as pd
import numpy as np
import os
import time
import spacy
from spacy import displacy
import string


from sentence_transformers import SentenceTransformer, util
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2025-09-26 10:31:46.013189: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
config = configparser.ConfigParser()
config.read("config.ini")

# access values
raw_path = Path(config["default"]["raw_path"])
interim_path = Path(config["default"]["interim_path"])
processed_path = Path(config["default"]["processed_path"])

# %%
df = pd.read_csv(interim_path/"tokenised_policy_incentives_country.csv") #tokenised_policy_incentives_subsectioned.csv
df
# Out:
#            country                                         text_clean
# 0          Austria  federal purchase subsidy scheme e mobilität 20...
# 1          Belgium  regional purchase subsidies are no longer avai...
# 2         Bulgaria  no purchase subsidies are currently available ...
# 3          Croatia  call for investment in zero emission vehicles ...
# 4           Cyprus  under national electromobility promotion schem...
# 5   Czech Republic  no purchase subsidies available in 2025 bevs f...
# 6          Denmark  no direct national purchase subsidies are avai...
# 7          Estonia  since december 2023 estonia no longer offers d...
# 8          Finland  2025 finland does not offer direct purchase su...
# 9           France  ecological bonus bonus écologique remains in p...
# 10         Germany  april 2025 germany no longer offers national p...
# 11          Greece  greece 's i move electrically 3 programme offe...
# 12         Hungary  bevs used for business purposes are exempt fro...
# 13         Iceland  grants for electric car purchases ranging from...
# 14         Ireland  sustainable energy authority ireland seai prov...
# 15           Italy  registration fee ipt italy has no co₂-based ca...
# 16          Latvia  2025 there are no active national purchase sub...
# 17   Liechtenstein  no national purchase subsidies for bevs in pla...
# 18       Lithuania  purchase incentives bonus for individuals in 2...
# 19      Luxembourg  maximum subsidy € 6,000 is available for new b...
# 20           Malta  cars m1 vans n1 ≤ 3,500 kg optional scrappage ...
# 21     Netherlands  no national purchase subsidies are available i...
# 22          Norway  no national purchase subsidies are available f...
# 23          Poland  naszeauto programme launched on 3 february 202...
# 24        Portugal  in 2025 private individuals in portugal can re...
# 25         Romania  conditions bevs are completely exempt from reg...
# 26        Slovakia  no direct bev purchase subsidies in place 2025...
# 27        Slovenia  private individuals can receive up to legal en...
# 28           Spain  spain 's moves iii programme extended through ...
# 29          Sweden  no bev specific registration tax benefit swede...
# 30     Switzerland  no federal purchase subsidies regional subsidi...
# 31          Turkey  no national direct purchase subsidies for bevs...
# 32  United Kingdom  electric car grant ecg introduced 16 july 2025...

# %% [markdown]
# #### Import sentence-transformer model.
# * Documentation on these options found here: https://www.sbert.net/docs/sentence_transformer/pretrained_models.html
# * Chose 'all' mini - because best general purpose model (out of those available), and was trained on all available training data.
# * 'Mini' version is faster, and small enough to run locally without any issues.
# * Encodes sentences in 384 dimensional space

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# Quick check that the model is working and returning values as expected

# %%
# TEST EMBEDDINGS
embeddings = model.encode(["Hello world"])
print(embeddings.shape)
# Out:
# (1, 384)

# %% [markdown]
# Now apply embeddings to cleaned policy text column, storing in a new embeddings column of same dataframe to keep metadata
# * for now, I haven't included section subheadings in the text - may explore doing so?

# %%
# apply embeddings model to policy text column - ensuring embeddings stored as (comma separated) list
df['embeddings'] = df['text_clean'].apply(lambda x: model.encode(x).tolist())

# check results
#print(df['embeddings'][0].shape)  # embedding dimension
df
# Out:
#            country                                         text_clean  \
# 0          Austria  federal purchase subsidy scheme e mobilität 20...
# 1          Belgium  regional purchase subsidies are no longer avai...
# 2         Bulgaria  no purchase subsidies are currently available ...
# 3          Croatia  call for investment in zero emission vehicles ...
# 4           Cyprus  under national electromobility promotion schem...
# 5   Czech Republic  no purchase subsidies available in 2025 bevs f...
# 6          Denmark  no direct national purchase subsidies are avai...
# 7          Estonia  since december 2023 estonia no longer offers d...
# 8          Finland  2025 finland does not offer direct purchase su...
# 9           France  ecological bonus bonus écologique remains in p...
# 10         Germany  april 2025 germany no longer offers national p...
# 11          Greece  greece 's i move electrically 3 programme offe...
# 12         Hungary  bevs used for business purposes are exempt fro...
# 13         Iceland  grants for electric car purchases ranging from...
# 14         Ireland  sustainable energy authority ireland seai prov...
# 15           Italy  registration fee ipt italy has no co₂-based ca...
# 16          Latvia  2025 there are no active national purchase sub...
# 17   Liechtenstein  no national purchase subsidies for bevs in pla...
# 18       Lithuania  purchase incentives bonus for individuals in 2...
# 19      Luxembourg  maximum subsidy € 6,000 is available for new b...
# 20           Malta  cars m1 vans n1 ≤ 3,500 kg optional scrappage ...
# 21     Netherlands  no national purchase subsidies are available i...
# 22          Norway  no national purchase subsidies are available f...
# 23          Poland  naszeauto programme launched on 3 february 202...
# 24        Portugal  in 2025 private individuals in portugal can re...
# 25         Romania  conditions bevs are completely exempt from reg...
# 26        Slovakia  no direct bev purchase subsidies in place 2025...
# 27        Slovenia  private individuals can receive up to legal en...
# 28           Spain  spain 's moves iii programme extended through ...
# 29          Sweden  no bev specific registration tax benefit swede...
# 30     Switzerland  no federal purchase subsidies regional subsidi...
# 31          Turkey  no national direct purchase subsidies for bevs...
# 32  United Kingdom  electric car grant ecg introduced 16 july 2025...
#
#                                            embeddings
# 0   [-0.03710819408297539, 0.02366330847144127, 0....
# 1   [-0.0001772841642377898, 0.028538541868329048,...
# 2   [-0.04008038714528084, 0.0288896132260561, 0.0...
# 3   [-0.003128104144707322, 0.044598959386348724, ...
# 4   [-0.025078408420085907, 0.06687013059854507, -...
# 5   [-0.04738859832286835, 0.05021532252430916, -0...
# 6   [-0.06332932412624359, 0.05011808127164841, 0....
# 7   [-0.029093794524669647, 0.003588747698813677, ...
# 8   [-0.06467203795909882, 0.0142294242978096, 0.0...
# 9   [0.018083663657307625, 0.05167808011174202, 0....
# 10  [-0.057525668293237686, 0.052466683089733124, ...
# 11  [-0.022195197641849518, -0.005566054489463568,...
# 12  [-0.03522709384560585, 0.0719553679227829, 0.0...
# 13  [0.025103390216827393, 0.0759718120098114, 0.0...
# 14  [-0.011061077937483788, 0.05922210216522217, 0...
# 15  [-0.05948859825730324, 0.042295850813388824, 0...
# 16  [0.003892142092809081, 0.0299688670784235, 0.0...
# 17  [0.005889396648854017, 0.03458963707089424, 0....
# 18  [-0.03245556727051735, 0.043385352939367294, 0...
# 19  [-0.0049318415112793446, 0.04454256221652031, ...
# 20  [-0.006640954874455929, 0.03328484296798706, 0...
# 21  [0.004553092643618584, 0.0013977139024063945, ...
# 22  [-0.03960096463561058, 0.05498113855719566, 0....
# 23  [-0.031296830624341965, 0.04275396838784218, 0...
# 24  [-0.0072783841751515865, 0.06753183901309967, ...
# 25  [0.007397414185106754, 0.008230657316744328, 0...
# 26  [-0.016775833442807198, 0.013068114407360554, ...
# 27  [-0.033889707177877426, -0.010085906833410263,...
# 28  [0.016015781089663506, -0.08454908430576324, 0...
# 29  [-0.006025165319442749, 0.01266432274132967, 0...
# 30  [-0.021737664937973022, 0.045501958578825, 0.0...
# 31  [-0.008700292557477951, 0.022796977311372757, ...
# 32  [0.017215006053447723, 0.04112536087632179, 0....

# %%
# save out DF with embeddings
df.to_csv(interim_path/"policy_embeddings_country.csv", index=False)
